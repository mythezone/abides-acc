# %%
import bz2
import pandas as pd 
from rich import print

# 替换成你的文件路径
exchange_agent_bz2_file_path = './log/rmsc03_two_hour/EXCHANGE_AGENT.bz2'
fundamental_ABM_bz2_file_path = './log/rmsc03_two_hour/fundamental_ABM.bz2'
order_book_bz2_file_path = './log/rmsc03_two_hour/ORDERBOOK_ABM_FULL.bz2'
pov_execution_bz2_file_path = './log/rmsc03_two_hour/POV_EXECUTION_AGENT.bz2'
summary_log = './log/rmsc03_two_hour/summary_log.bz2' 

# # 打开并读取 bz2 文件内容
# with bz2.open(summary_log, 'r', encoding='utf-8') as f:
#     content = f.read()
#     df = pd.read_csv(content, sep='|')


def read_bz2(file_path,show=True,head=100):
    df = pd.read_pickle(file_path,compression='bz2')
    if show:
        print(df.head(head))
    return df

content = read_bz2(summary_log)
# Out:
#     AgentID AgentStrategy      EventType       Event
# 0         1    NoiseAgent  STARTING_CASH  10000000.0
# 1         2    NoiseAgent  STARTING_CASH  10000000.0
# 2         3    NoiseAgent  STARTING_CASH  10000000.0
# 3         4    NoiseAgent  STARTING_CASH  10000000.0
# 4         5    NoiseAgent  STARTING_CASH  10000000.0
# ..      ...           ...            ...         ...
# 95       96    NoiseAgent  STARTING_CASH  10000000.0
# 96       97    NoiseAgent  STARTING_CASH  10000000.0
# 97       98    NoiseAgent  STARTING_CASH  10000000.0
# 98       99    NoiseAgent  STARTING_CASH  10000000.0
# 99      100    NoiseAgent  STARTING_CASH  10000000.0
#
# [100 rows x 4 columns]

# %%
df = read_bz2(order_book_bz2_file_path,show=True)

print(df.shape,df.columns)
# Out:
#                                95497   95921   96345   96769   97193   97617   \
# QuoteTime
# 2020-06-03 09:30:00.000007378       0       0       0       0       0       0
# 2020-06-03 09:30:00.000014788       0       0       0       0       0       0
# 2020-06-03 09:30:00.000023509       0       0       0       0       0       0
# 2020-06-03 09:30:00.000046092       0       0       0       0       0       0
# 2020-06-03 09:30:00.000054438       0       0       0       0       0       0
# ...                               ...     ...     ...     ...     ...     ...
# 2020-06-03 09:30:00.001525436       0       0       0       0       0       0
# 2020-06-03 09:30:00.001542337       0       0       0       0       0       0
# 2020-06-03 09:30:00.001548822       0       0       0       0       0       0
# 2020-06-03 09:30:00.001556312       0       0       0       0       0       0
# 2020-06-03 09:30:00.001557265       0       0       0       0       0       0
#
# ...

# %%
read_bz2(exchange_agent_bz2_file_path,show=True)
# Out:
#                                     EventType          Event
# EventTime
# NaT                                AGENT_TYPE  ExchangeAgent
# 2020-06-03 00:00:00.000002456   WHEN_MKT_OPEN           5027
# 2020-06-03 00:00:00.000002456  WHEN_MKT_CLOSE           5027
# 2020-06-03 00:00:00.000002815   WHEN_MKT_OPEN           3885
# 2020-06-03 00:00:00.000002815  WHEN_MKT_CLOSE           3885
# ...                                       ...            ...
# 2020-06-03 00:00:00.000056069   WHEN_MKT_OPEN           3958
# 2020-06-03 00:00:00.000056069  WHEN_MKT_CLOSE           3958
# 2020-06-03 00:00:00.000058862   WHEN_MKT_OPEN           1905
# 2020-06-03 00:00:00.000058862  WHEN_MKT_CLOSE           1905
# 2020-06-03 00:00:00.000058879   WHEN_MKT_OPEN           1134
#
# [100 rows x 2 columns]
#                                     EventType          Event
# EventTime
# NaT                                AGENT_TYPE  ExchangeAgent
# 2020-06-03 00:00:00.000002456   WHEN_MKT_OPEN           5027
# ...

# %%
read_bz2(fundamental_ABM_bz2_file_path,show=True)
# Out:
#                                FundamentalValue
# FundamentalTime
# 2020-06-03 09:30:00.000000000          100000.0
# 2020-06-03 09:30:00.000004922          100000.0
# 2020-06-03 09:30:00.000009848          100000.0
# 2020-06-03 09:30:00.000186552          100000.0
# 2020-06-03 09:30:00.000225743          100000.0
# ...                                         ...
# 2020-06-03 09:30:00.024389410          100000.0
# 2020-06-03 09:30:00.025309437          100000.0
# 2020-06-03 09:30:00.025320689          100000.0
# 2020-06-03 09:30:00.025343945          100000.0
# 2020-06-03 09:30:00.025422578          100000.0
#
# [100 rows x 1 columns]
#                                FundamentalValue
# FundamentalTime
# 2020-06-03 09:30:00.000000000          100000.0
# 2020-06-03 09:30:00.000004922          100000.0
# 2020-06-03 09:30:00.000009848          100000.0
# 2020-06-03 09:30:00.000186552          100000.0
# 2020-06-03 09:30:00.000225743          100000.0
# ...

# %%
read_bz2(pov_execution_bz2_file_path,show=True)
# Out:
#                                          EventType               Event
# EventTime
# NaT                                     AGENT_TYPE      ExecutionAgent
# NaT                                  STARTING_CASH            10000000
# 2020-06-03 00:00:00.000000000     HOLDINGS_UPDATED  {'CASH': 10000000}
# 2020-06-03 11:31:00.000000050       FINAL_HOLDINGS  { CASH: 10000000 }
# 2020-06-03 11:31:00.000000050  FINAL_CASH_POSITION            10000000
# 2020-06-03 11:31:00.000000050     MARKED_TO_MARKET            10000000
# 2020-06-03 11:31:00.000000050          ENDING_CASH            10000000
#                                          EventType               Event
# EventTime
# NaT                                     AGENT_TYPE      ExecutionAgent
# NaT                                  STARTING_CASH            10000000
# 2020-06-03 00:00:00.000000000     HOLDINGS_UPDATED  {'CASH': 10000000}
# 2020-06-03 11:31:00.000000050       FINAL_HOLDINGS  { CASH: 10000000 }
# ...
