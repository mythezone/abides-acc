# %%
from core.kernel import Kernel

k = Kernel()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from core.kernel import Kernel
#       3 k = Kernel()
#
# File ~/project/gitlab/abides-acc/core/kernel.py:15
#      13 from core.config import ConfigManager as CM
#      14 from core.symbol import Symbol
# ---> 15 from agent import Agent, agents
#      16 from core import exchange
#      17 from core.message import MessageBox, MessageType, Message
#
# File ~/project/gitlab/abides-acc/agent/__init__.py:2
#       1 from agent.base import Agent
# ----> 2 from agent.trading_agent import TradingAgent
#       3 from agent.noise_agent import NoiseAgent
#       4 from agent.value_agent import ValueAgent
#
# File ~/project/gitlab/abides-acc/agent/trading_agent.py:2
#       1 from agent.base import Agent
# ----> 2 from core.exchange import Exchange
#       3 from core.message import Message
# ...
